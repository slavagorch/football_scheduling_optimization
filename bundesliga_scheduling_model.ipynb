# %%
import pandas as pd
import plotly.graph_objects as go
from haversine import haversine_vector
from scipy.spatial.distance import pdist
from scipy.spatial.distance import squareform

# %%
ACCESS_TOKEN = "pk.eyJ1IjoiZ29yY2hha292dnYiLCJhIjoiY2xrd2prMzkzMDN0ajNkbnp0bjBheXcxZiJ9.UyiKwYPxhFvUWdUgRUbI6w"

# %%
last_season_results_df = pd.read_csv("D1_21-22.csv")
stadium_coords_df = pd.read_csv("stadiums-with-GPS-coordinates.csv")
last_season_results_df.head()
# Out:
#   Div        Date   Time      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  D1  13/08/2021  19:30    M'gladbach   Bayern Munich     1     1   D     1
# 1  D1  14/08/2021  14:30      Augsburg      Hoffenheim     0     4   A     0
# 2  D1  14/08/2021  14:30     Bielefeld        Freiburg     0     0   D     0
# 3  D1  14/08/2021  14:30     Stuttgart  Greuther Furth     5     1   H     2
# 4  D1  14/08/2021  14:30  Union Berlin      Leverkusen     1     1   D     1
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     1  ...     3.01  0.75      1.99      1.94   1.99   1.93     2.10
# 1     1  ...     2.30  0.25      1.97      1.96   1.98   1.94     2.02
# 2     0  ...     1.64  0.25      1.75      2.05   1.79   2.16     1.80
# 3     0  ...     2.16 -0.75      2.02      1.77   2.09   1.83     2.12
# 4     1  ...     1.76  0.00      1.92      2.01   1.92   2.01     1.95
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     1.96     1.98     1.88
# 1     1.99     1.96     1.91
# 2     2.20     1.76     2.12
# 3     1.86     2.07     1.80
# 4     2.02     1.91     1.96
#
# [5 rows x 105 columns]

# %%
teams_coords_df = stadium_coords_df.loc[stadium_coords_df["FDCOUK"].isin(last_season_results_df["HomeTeam"])]

# %%
last_season_results_df["HomeTeam"].unique()
# Out:
# array(["M'gladbach", 'Augsburg', 'Bielefeld', 'Stuttgart', 'Union Berlin',
#        'Wolfsburg', 'Dortmund', 'Mainz', 'FC Koln', 'RB Leipzig',
#        'Bochum', 'Ein Frankfurt', 'Freiburg', 'Greuther Furth', 'Hertha',
#        'Leverkusen', 'Hoffenheim', 'Bayern Munich'], dtype=object)

# %%
set(last_season_results_df["HomeTeam"]) - set(teams_coords_df["FDCOUK"])
# Out:
# {'Bielefeld', 'Bochum', 'RB Leipzig', 'Union Berlin'}

# %%
missing_data = {
    'Team': ['Arminia Bielefeld', 'VfL Bochum', 'RB Leipzig', 'Union Berlin'],
    'FDCOUK': ['Bielefeld', 'Bochum', 'RB Leipzig', 'Union Berlin'],
    'City': ['Bielefeld', 'Bochum', 'Leipzig', 'Berlin'],
    'Stadium': ['SchücoArena', 'Vonovia Ruhrstadion', 'Red Bull Arena', 'Stadion An der Alten Försterei'],
    'Capacity': [27240, 30272, 42500, 22706],
    'Latitude': [52.021168, 51.481663, 51.345261, 52.453489],
    'Longitude': [8.541486, 7.222778, 12.361012, 13.288811],
    'Country': ['Germany', 'Germany', 'Germany', 'Germany']
}
missing_df = pd.DataFrame(missing_data)
missing_df
# Out:
#                 Team        FDCOUK       City                         Stadium  \
# 0  Arminia Bielefeld     Bielefeld  Bielefeld                     SchücoArena
# 1         VfL Bochum        Bochum     Bochum             Vonovia Ruhrstadion
# 2         RB Leipzig    RB Leipzig    Leipzig                  Red Bull Arena
# 3       Union Berlin  Union Berlin     Berlin  Stadion An der Alten Försterei
#
#    Capacity   Latitude  Longitude  Country
# 0     27240  52.021168   8.541486  Germany
# 1     30272  51.481663   7.222778  Germany
# 2     42500  51.345261  12.361012  Germany
# 3     22706  52.453489  13.288811  Germany

# %%
teams_coords_df
# Out:
#                          Team          FDCOUK              City  \
# 62               FC Augsburg         Augsburg         Augsburg
# 63          Bayer Leverkusen       Leverkusen       Leverkusen
# 64             Bayern Munich    Bayern Munich           Munich
# 65         Borussia Dortmund         Dortmund         Dortmund
# 66  Borussia Mönchengladbach       M'gladbach  Mönchengladbach
# 68       Eintracht Frankfurt    Ein Frankfurt        Frankfurt
# 69               SC Freiburg         Freiburg         Freiburg
# 72                Hertha BSC           Hertha           Berlin
# 73       TSG 1899 Hoffenheim       Hoffenheim         Sinsheim
# 74           1. FSV Mainz 05            Mainz            Mainz
# 77             VfB Stuttgart        Stuttgart        Stuttgart
# 79             VfL Wolfsburg        Wolfsburg        Wolfsburg
# 81      SpVgg Greuther Fürth   Greuther Furth            Fürth
# 83                1. FC Köln          FC Koln          Cologne
#
#                  Stadium  Capacity   Latitude  Longitude  Country
# 62            SGL arena      30660  48.322500  10.882222  Germany
# 63             BayArena      30210  51.038256   7.002206  Germany
# 64        Allianz Arena      71000  48.218775  11.624753  Germany
# 65    Signal Iduna Park      80645  51.492569   7.451842  Germany
# 66        Borussia-Park      54010  51.174583   6.385464  Germany
# 68    Commerzbank-Arena      51500  50.068572   8.645458  Germany
# 69   MAGE SOLAR Stadion      24000  47.988889   7.893056  Germany
# 72       Olympiastadion      74244  52.514722  13.239444  Germany
# 73   Rhein-Neckar Arena      30150  49.239008   8.888281  Germany
# 74         Coface Arena      34000  49.984167   8.224167  Germany
# 77  Mercedes-Benz Arena      60441  48.792269   9.232031  Germany
# 79     Volkswagen Arena      30000  52.431944  10.803889  Germany
# 81         Trolli Arena      18000  49.486944  10.999167  Germany
# 83  RheinEnergieStadion      50000  50.933497   6.874997  Germany

# %%
TABLE_COORDS_COLUMNS = {
    "FDCOUK": "team",
    "Latitude": "lat",
    "Longitude": "lon"
}
all_teams_coords_df = pd.concat([teams_coords_df, missing_df], axis=0)
all_teams_coords_df = all_teams_coords_df[["FDCOUK", "Latitude", "Longitude"]].rename(columns=TABLE_COORDS_COLUMNS)[
        TABLE_COORDS_COLUMNS.values()]
all_teams_coords_df
# Out:
#               team        lat        lon
# 62        Augsburg  48.322500  10.882222
# 63      Leverkusen  51.038256   7.002206
# 64   Bayern Munich  48.218775  11.624753
# 65        Dortmund  51.492569   7.451842
# 66      M'gladbach  51.174583   6.385464
# 68   Ein Frankfurt  50.068572   8.645458
# 69        Freiburg  47.988889   7.893056
# 72          Hertha  52.514722  13.239444
# 73      Hoffenheim  49.239008   8.888281
# 74           Mainz  49.984167   8.224167
# 77       Stuttgart  48.792269   9.232031
# 79       Wolfsburg  52.431944  10.803889
# 81  Greuther Furth  49.486944  10.999167
# 83         FC Koln  50.933497   6.874997
# 0        Bielefeld  52.021168   8.541486
# 1           Bochum  51.481663   7.222778
# 2       RB Leipzig  51.345261  12.361012
# 3     Union Berlin  52.453489  13.288811

# %%
# quick plot of teams location on map
fig = go.Figure()
fig.add_trace(
        go.Scattermapbox(
            mode="markers+text",
            lat=all_teams_coords_df.lat.tolist(),
            lon=all_teams_coords_df.lon.tolist(),
            marker={"size": 10, "color": "black"},
            hovertext=all_teams_coords_df.team,
        )
    )
fig.update_layout(mapbox={
        "accesstoken": ACCESS_TOKEN,
        "zoom": 5,
        "center": {
            "lat": pd.concat([all_teams_coords_df.lat, all_teams_coords_df.lat], axis=0).mean(),
            "lon": pd.concat([all_teams_coords_df.lon, all_teams_coords_df.lon], axis=0).mean(),
        },
    },
    margin=dict(l=0, r=0, t=0, b=0),
    showlegend=False,
)

fig.show()
fig.write_image("../bundesliga_teams_coords.png")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_27.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# compute matrix of haversine distances among teams
#teams_distance_matrix_df = haversine_vector(all_teams_coords_df[["lat", "lon"]], all_teams_coords_df[["lat", "lon"]])
teams_distance_matrix_df = pd.DataFrame([haversine_vector([[row.lat, row.lon]] * len(all_teams_coords_df), all_teams_coords_df[["lat", "lon"]]) for index, row in all_teams_coords_df.iterrows()], columns = all_teams_coords_df.team, index = all_teams_coords_df.team
)
teams_distance_matrix_df
# Out:
# team              Augsburg  Leverkusen  Bayern Munich    Dortmund  M'gladbach  \
# team
# Augsburg          0.000000  411.132977      56.153853  429.545970  452.565843
# Leverkusen      411.132977    0.000000     457.154331   59.419368   45.649148
# Bayern Munich    56.153853  457.154331       0.000000  471.019883  499.808700
# Dortmund        429.545970   59.419368     471.019883    0.000000   82.088744
# M'gladbach      452.565843   45.649148     499.808700   82.088744    0.000000
# Ein Frankfurt   253.180436  158.434476     298.740606  179.199654  201.340475
# Freiburg        224.800381  345.113023     278.242693  390.877881  370.511453
# Hertha          495.099060  459.267548     491.191285  412.029207  493.633057
# Hoffenheim      178.121166  241.011021     230.532655  270.492200  279.337266
# Mainz           267.378038  145.612423     315.896523  176.309967  185.400096
# Stuttgart       132.202001  296.382905     187.446756  325.934588  334.006189
# Wolfsburg       456.983639  304.166905     472.085225  252.274550  334.359019
# Greuther Furth  129.762217  332.315154     148.255148  335.657972  377.344114
# FC Koln         409.270596   14.662233     456.351803   74.020313   43.467083
# Bielefeld       443.715022  152.582570     476.433124   95.286179  176.167344
# Bochum          438.162863   51.638336     480.704220   15.906709   67.457342
# RB Leipzig      352.433034  374.915214     351.640743  340.749501  416.123525
# Union Berlin    489.937409  460.345600     485.429118  413.731485  495.178120
#
# team            Ein Frankfurt    Freiburg      Hertha  Hoffenheim       Mainz  \
# team
# Augsburg           253.180436  224.800381  495.099060  178.121166  267.378038
# Leverkusen         158.434476  345.113023  459.267548  241.011021  145.612423
# Bayern Munich      298.740606  278.242693  491.191285  230.532655  315.896523
# Dortmund           179.199654  390.877881  412.029207  270.492200  176.309967
